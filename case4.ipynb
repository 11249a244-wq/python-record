# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a244-wq/python-record/blob/main/case4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Example Usage of Conversion Functions

# %%
# Example for binary_to_decimal
binary_num = "10110"
decimal_result = binary_to_decimal(binary_num)
print(f"Binary '{binary_num}' is Decimal: {decimal_result}")

binary_num_2 = "11111111"
decimal_result_2 = binary_to_decimal(binary_num_2)
print(f"Binary '{binary_num_2}' is Decimal: {decimal_result_2}")
# Out:
# Binary '10110' is Decimal: 22
# Binary '11111111' is Decimal: 255
