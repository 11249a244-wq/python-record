# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a244-wq/python-record/blob/main/case5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Q5=""" 5. Sentence Statistics: Write a Python program that accepts a sentence and find the number of words, digits, uppercase letters.
"""
print(Q5)
sentence = input("Enter a sentence: ")
# Count words
words = sentence.split()
num_words = len(words)
# Initialize counters
num_digits = 0
num_uppercase = 0
num_lowercase = 0
# Count digits and letters
for char in sentence:
    if char.isdigit():
        num_digits += 1
    elif char.isupper():
        num_uppercase += 1
    elif char.islower():
        num_lowercase += 1
print("Number of words:", num_words)
print("Number of digits:", num_digits)
print("Number of uppercase letters:", num_uppercase)
print("Number of lowercase letters:", num_lowercase)
# Out:
#  5. Sentence Statistics: Write a Python program that accepts a sentence and find the number of words, digits, uppercase letters.
#
# Enter a sentence: 44
# Number of words: 1
# Number of digits: 2
# Number of uppercase letters: 0
# Number of lowercase letters: 0
